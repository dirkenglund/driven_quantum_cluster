# %%
from quantum_percolation_simulation import SimulationConfig, create_animation, save_animation

# %%
# Create configuration (you can modify these parameters)
config = SimulationConfig(
    n=20,        # Size of the lattice (n x n)
    steps=80,    # Number of time steps
    p_trial=0.1, # Probability of establishing entanglement
    p_error=0.01,# Probability of error
    fps=2        # Animation frames per second
)

# Create and display animation
animation, pos = create_animation(config)
display_image = save_animation(animation, config)
display_image
# Out:
# Starting simulation with 20x20 lattice for 80 steps
# Trial probability: 0.1, Error probability: 0.01
# Simulating:   0%|          | 0/80 [00:00<?, ?it/s]
