# %%
from cantilever_cc_simulation import SimulationConfig, create_color_centers, animate_phase_space

# %%
from cantilever_cc_simulation import SimulationConfig, create_color_centers, animate_phase_space
from IPython.display import HTML

# Create configuration and color centers
config = SimulationConfig()
color_centers = create_color_centers(config)

# Create and display animation
ani = animate_phase_space(color_centers, config)
HTML(ani.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[13], line 9
#       6 color_centers = create_color_centers(config)
#       8 # Create and display animation
# ----> 9 ani = animate_phase_space(color_centers, config)
#      10 HTML(ani.to_jshtml())
#
# File ~/Projects/202501.cluster_state_sandro/quantum_simulation/cantilever_cc_simulation.py:114, in animate_phase_space(color_centers, config)
#     111     fig, ax, edges = plot_phase_space(color_centers, config, displacement, fig, ax)
#     112     return ax,
# --> 114 ani = FuncAnimation(fig, update, frames=100, interval=100, blit=True)
#     115 plt.close(fig)  # Prevent display of static figure
#     116 return ani
#
# ...
